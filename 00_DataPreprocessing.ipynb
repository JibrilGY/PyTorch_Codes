# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# 1. Load data and apply AlexNet-compatible transformations (Resize to 224x224)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)) # MNIST standard mean and std
])



train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# 2. Instantiate and modify AlexNet
model = torchvision.models.alexnet(weights=None) # Training from scratch

# Change input layer: 3 channels -> 1 channel
model.features[0] = nn.Conv2d(1, 64, kernel_size=11, stride=4, padding=2)

# Change output layer: 1000 classes -> 10 classes
model.classifier[6] = nn.Linear(model.classifier[6].in_features, 10)

# 3. Define Loss & Optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

print(model)
