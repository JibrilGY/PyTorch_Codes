# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class YOLOv3(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_initial = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=1, padding=1)
        self.down1 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3,3), stride=2, padding=1)
        self.stage1_block1_conv1 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(1,1), stride=1, padding=0)
        self.stage1_block1_conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3,3), stride=1, padding=1)
        self.down2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3,3), stride=2, padding=1)
        self.stage2_block1_conv1 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(1,1), stride=1, padding=0)
        self.stage2_block1_conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3,3), stride=1, padding=1)
        self.stage2_block2_conv1 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(1,1), stride=1, padding=0)
        self.stage2_block2_conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3,3), stride=1, padding=1)
        self.down3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=2, padding=1)
        self.stage3_block1_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block1_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block2_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block2_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block3_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block3_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block4_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block4_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block5_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block5_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block6_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block6_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block7_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block7_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.stage3_block8_conv1 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.stage3_block8_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.down4 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=2, padding=1)
        self.stage4_block1_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block1_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block2_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block2_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block3_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block3_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block4_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block4_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block5_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block5_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block6_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block6_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block7_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block7_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.stage4_block8_conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.stage4_block8_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.down5 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=2, padding=1)
        self.stage5_block1_conv1 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.stage5_block1_conv2 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.stage5_block2_conv1 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.stage5_block2_conv2 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.stage5_block3_conv1 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.stage5_block3_conv2 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.stage5_block4_conv1 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.stage5_block4_conv2 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.head13_conv1 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.head13_conv2 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.head13_conv3 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.head13_conv4 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.head13_conv5 = nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(1,1), stride=1, padding=0)
        self.head13_conv6 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=(3,3), stride=1, padding=1)
        self.pred13 = nn.Conv2d(in_channels=1024, out_channels=255, kernel_size=(1,1), stride=1, padding=0)
        self.reduce13_to26 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.head26_conv1 = nn.Conv2d(in_channels=768, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.head26_conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.head26_conv3 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.head26_conv4 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.head26_conv5 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=(1,1), stride=1, padding=0)
        self.head26_conv6 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3,3), stride=1, padding=1)
        self.pred26 = nn.Conv2d(in_channels=512, out_channels=255, kernel_size=(1,1), stride=1, padding=0)
        self.reduce26_to52 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.head52_conv1 = nn.Conv2d(in_channels=384, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.head52_conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.head52_conv3 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.head52_conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.head52_conv5 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=(1,1), stride=1, padding=0)
        self.head52_conv6 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3,3), stride=1, padding=1)
        self.pred52 = nn.Conv2d(in_channels=256, out_channels=255, kernel_size=(1,1), stride=1, padding=0)

        self.batchnorm1 = nn.BatchNorm2d(32)
        self.batchnorm_down1 = nn.BatchNorm2d(64)
        self.batchnorm_stage1_block1_conv1 = nn.BatchNorm2d(32)
        self.batchnorm_stage1_block1_conv2 = nn.BatchNorm2d(64)
        self.batchnorm_down2 = nn.BatchNorm2d(128)
        self.batchnorm_stage2_block1_conv1 = nn.BatchNorm2d(64)
        self.batchnorm_stage2_block1_conv2 = nn.BatchNorm2d(128)
        self.batchnorm_stage2_block2_conv1 = nn.BatchNorm2d(64)
        self.batchnorm_stage2_block2_conv2 = nn.BatchNorm2d(128)
        self.batchnorm_down3 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block1_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block1_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block2_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block2_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block3_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block3_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block4_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block4_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block5_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block5_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block6_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block6_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block7_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block7_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_stage3_block8_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_stage3_block8_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_down4 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block1_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block1_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block2_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block2_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block3_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block3_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block4_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block4_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block5_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block5_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block6_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block6_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block7_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block7_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_stage4_block8_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_stage4_block8_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_down5 = nn.BatchNorm2d(1024)
        self.batchnorm_stage5_block1_conv1 = nn.BatchNorm2d(512)
        self.batchnorm_stage5_block1_conv2 = nn.BatchNorm2d(1024)
        self.batchnorm_stage5_block2_conv1 = nn.BatchNorm2d(512)
        self.batchnorm_stage5_block2_conv2 = nn.BatchNorm2d(1024)
        self.batchnorm_stage5_block3_conv1 = nn.BatchNorm2d(512)
        self.batchnorm_stage5_block3_conv2 = nn.BatchNorm2d(1024)
        self.batchnorm_stage5_block4_conv1 = nn.BatchNorm2d(512)
        self.batchnorm_stage5_block4_conv2 = nn.BatchNorm2d(1024)
        self.batchnorm_head13_conv1 = nn.BatchNorm2d(512)
        self.batchnorm_head13_conv2 = nn.BatchNorm2d(1024)
        self.batchnorm_head13_conv3 = nn.BatchNorm2d(512)
        self.batchnorm_head13_conv4 = nn.BatchNorm2d(1024)
        self.batchnorm_head13_conv5 = nn.BatchNorm2d(512)
        self.batchnorm_head13_conv6 = nn.BatchNorm2d(1024)
        self.batchnorm_reduce13_to26 = nn.BatchNorm2d(256)
        self.batchnorm_head26_conv1 = nn.BatchNorm2d(256)
        self.batchnorm_head26_conv2 = nn.BatchNorm2d(512)
        self.batchnorm_head26_conv3 = nn.BatchNorm2d(256)
        self.batchnorm_head26_conv4 = nn.BatchNorm2d(512)
        self.batchnorm_head26_conv5 = nn.BatchNorm2d(256)
        self.batchnorm_head26_conv6 = nn.BatchNorm2d(512)
        self.batchnorm_head52_conv1 = nn.BatchNorm2d(128)
        self.batchnorm_head52_conv2 = nn.BatchNorm2d(256)
        self.batchnorm_head52_conv3 = nn.BatchNorm2d(128)
        self.batchnorm_head52_conv4 = nn.BatchNorm2d(256)
        self.batchnorm_head52_conv5 = nn.BatchNorm2d(128)
        self.batchnorm_head52_conv6 = nn.BatchNorm2d(256)
        self.batchnorm_reduce26_to52 = nn.BatchNorm2d(128)

        self.upsample = nn.Upsample(scale_factor=2)

    def forward(self,x):
        x = F.leaky_relu(self.batchnorm1(self.conv_initial(x)))
        x = F.leaky_relu(self.batchnorm_down1(self.down1(x)))
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage1_block1_conv1(self.stage1_block1_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage1_block1_conv2(self.stage1_block1_conv2(x)))
        x = x + x_copy
        x = F.leaky_relu(self.batchnorm_down2(self.down2(x)))
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage2_block1_conv1(self.stage2_block1_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage2_block1_conv2(self.stage2_block1_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage2_block2_conv1(self.stage2_block2_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage2_block2_conv2(self.stage2_block2_conv2(x)))
        x = x + x_copy
        x = F.leaky_relu(self.batchnorm_down3(self.down3(x)))
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block1_conv1(self.stage3_block1_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block1_conv2(self.stage3_block1_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block2_conv1(self.stage3_block2_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block2_conv2(self.stage3_block2_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block3_conv1(self.stage3_block3_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block3_conv2(self.stage3_block3_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block4_conv1(self.stage3_block4_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block4_conv2(self.stage3_block4_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block5_conv1(self.stage3_block5_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block5_conv2(self.stage3_block5_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block6_conv1(self.stage3_block6_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block6_conv2(self.stage3_block6_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block7_conv1(self.stage3_block7_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block7_conv2(self.stage3_block7_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage3_block8_conv1(self.stage3_block8_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage3_block8_conv2(self.stage3_block8_conv2(x)))
        x = x + x_copy
        route52 = x.clone()
        x = F.leaky_relu(self.batchnorm_down4(self.down4(x)))
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block1_conv1(self.stage4_block1_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block1_conv2(self.stage4_block1_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block2_conv1(self.stage4_block2_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block2_conv2(self.stage4_block2_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block3_conv1(self.stage4_block3_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block3_conv2(self.stage4_block3_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block4_conv1(self.stage4_block4_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block4_conv2(self.stage4_block4_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block5_conv1(self.stage4_block5_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block5_conv2(self.stage4_block5_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block6_conv1(self.stage4_block6_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block6_conv2(self.stage4_block6_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block7_conv1(self.stage4_block7_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block7_conv2(self.stage4_block7_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage4_block8_conv1(self.stage4_block8_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage4_block8_conv2(self.stage4_block8_conv2(x)))
        x = x + x_copy
        route26 = x.clone()
        x = F.leaky_relu(self.batchnorm_down5(self.down5(x)))
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage5_block1_conv1(self.stage5_block1_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage5_block1_conv2(self.stage5_block1_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage5_block2_conv1(self.stage5_block2_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage5_block2_conv2(self.stage5_block2_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage5_block3_conv1(self.stage5_block3_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage5_block3_conv2(self.stage5_block3_conv2(x)))
        x = x + x_copy
        x_copy = x.clone()
        x = F.leaky_relu(self.batchnorm_stage5_block4_conv1(self.stage5_block4_conv1(x)))
        x = F.leaky_relu(self.batchnorm_stage5_block4_conv2(self.stage5_block4_conv2(x)))
        x = x + x_copy
        x = F.leaky_relu(self.batchnorm_head13_conv1(self.head13_conv1(x)))
        x = F.leaky_relu(self.batchnorm_head13_conv2(self.head13_conv2(x)))
        x = F.leaky_relu(self.batchnorm_head13_conv3(self.head13_conv3(x)))
        x = F.leaky_relu(self.batchnorm_head13_conv4(self.head13_conv4(x)))
        x = F.leaky_relu(self.batchnorm_head13_conv5(self.head13_conv5(x)))
        route13 = x.clone()
        x = F.leaky_relu(self.batchnorm_head13_conv6(self.head13_conv6(x)))
        prediction13 = self.pred13(x)
        route13 = F.leaky_relu(self.batchnorm_reduce13_to26(self.reduce13_to26(route13)))
        route13 = self.upsample(route13)
        x = torch.cat(tensors=(route13, route26), dim=1)
        x = F.leaky_relu(self.batchnorm_head26_conv1(self.head26_conv1(x)))
        x = F.leaky_relu(self.batchnorm_head26_conv2(self.head26_conv2(x)))
        x = F.leaky_relu(self.batchnorm_head26_conv3(self.head26_conv3(x)))
        x = F.leaky_relu(self.batchnorm_head26_conv4(self.head26_conv4(x)))
        x = F.leaky_relu(self.batchnorm_head26_conv5(self.head26_conv5(x)))
        head_route26 = x.clone()
        x = F.leaky_relu(self.batchnorm_head26_conv6(self.head26_conv6(x)))
        prediction26 = self.pred26(x)
        head_route26 = F.leaky_relu(self.batchnorm_reduce26_to52(self.reduce26_to52(head_route26)))
        head_route26 = self.upsample(head_route26)
        x = torch.cat(tensors=(route52, head_route26), dim=1)
        x = F.leaky_relu(self.batchnorm_head52_conv1(self.head52_conv1(x)))
        x = F.leaky_relu(self.batchnorm_head52_conv2(self.head52_conv2(x)))
        x = F.leaky_relu(self.batchnorm_head52_conv3(self.head52_conv3(x)))
        x = F.leaky_relu(self.batchnorm_head52_conv4(self.head52_conv4(x)))
        x = F.leaky_relu(self.batchnorm_head52_conv5(self.head52_conv5(x)))
        x = F.leaky_relu(self.batchnorm_head52_conv6(self.head52_conv6(x)))
        prediction52 = self.pred52(x)

        return prediction13, prediction26, prediction52
